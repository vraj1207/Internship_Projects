# %% [markdown]
# # Micro Credit Defaulter Project

# %% [markdown]
# Problem Statement:-
#
# A Microfinance Institution (MFI) is an organization that offers financial services to low income populations. MFS becomes very
# useful when targeting especially the unbanked poor families living in remote areas with not much sources of income. The
# Microfinance services (MFS) provided by MFI are Group Loans, Agricultural Loans, Individual Business Loans and so on. Many
# microfinance institutions (MFI), experts and donors are supporting the idea of using mobile financial services (MFS) which they
# feel are more convenient and efficient, and cost saving, than the traditional high-touch model used since long for the purpose
# of delivering microfinance services. Though, the MFI industry is primarily focusing on low income families and are very useful
# in such areas, the implementation of MFS has been uneven with both significant challenges and successes.
# Today, microfinance is widely accepted as a poverty-reduction tool, representing $70 billion in outstanding loans and a global
# outreach of 200 million clients.We are working with one such client that is in Telecom Industry. They are a fixed wireless
# telecommunications network provider. They have launched various products and have developed its business and organization based
# on the budget operator model, offering better products at Lower Prices to all value conscious customers through a strategy of
# disruptive innovation that focuses on the subscriber.They understand the importance of communication and how it affects a
# person’s life, thus, focusing on providing their services and products to low income families and poor customers that can help
# them in the need of hour.They are collaborating with an MFI to provide micro-credit on mobile balances to be paid back in
# 5 days. The Consumer is believed to be defaulter if he deviates from the path of paying back the loaned amount within the time
# duration of 5 days. For the loan amount of 5 (in Indonesian Rupiah), payback amount should be 6 (in Indonesian Rupiah), while,
# for the loan amount of 10 (in Indonesian Rupiah), the payback amount should be 12 (in Indonesian Rupiah). The sample data is
# provided to us from our client database. It is hereby given to you for this exercise. In order to improve the
# selection of customers for the credit, the client wants some predictions that could help them in further investment and
# improvement in selection of customers.

# %% [markdown]
# Dataset Description:-
#
# For building the model for my client i am using client dataset and there are some features in the dataset which is listed below
# :-
#
# label ->Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}
#
# msisdn -> mobile number of user
#
# aon ->	age on cellular network in days
#
# daily_decr30 -> Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)
#
# daily_decr90 -> Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)
#
# rental30 -> Average main account balance over last 30 days
#
# rental90 ->	Average main account balance over last 90 days
#
# last_rech_date_ma -> Number of days till last recharge of main account
#
# last_rech_date_da ->	Number of days till last recharge of data account
#
# last_rech_amt_ma ->	Amount of last recharge of main account (in Indonesian Rupiah)
#
# cnt_ma_rech30 ->	Number of times main account got recharged in last 30 days
#
# fr_ma_rech30 ->	Frequency of main account recharged in last 30 days
#
# sumamnt_ma_rech30 ->	Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)
#
# medianamnt_ma_rech30 ->	Median of amount of recharges done in main account over last 30 days at user level                                            (in Indonesian      Rupiah)
#
# medianmarechprebal30 ->	Median of main account balance just before recharge in last 30 days at user level(in Indonesian Rupiah)
#
# cnt_ma_rech90 -> Number of times main account got recharged in last 90 days
#
# fr_ma_rech90 ->	Frequency of main account recharged in last 90 days
#
# sumamnt_ma_rech90 -> Total amount of recharge in main account over last 90 days (in Indonasian Rupiah)
# medianamnt_ma_rech90 ->	Median of amount of recharges done in main account over last 90 days at user level(in IndonasianRupiah)
#
# medianmarechprebal90 ->Median of main account balance just before recharge in last 90 days at user level(in Indonasian Rupiah)
#
# cnt_da_rech30 -> Number of times data account got recharged in last 30 days
#
# fr_da_rech30 ->	Frequency of data account recharged in last 30 days
#
# cnt_da_rech90 ->	Number of times data account got recharged in last 90 days
#
# fr_da_rech90 ->	Frequency of data account recharged in last 90 days
#
# cnt_loans30	 -> Number of loans taken by user in last 30 days
#
# amnt_loans30 ->	Total amount of loans taken by user in last 30 days
#
# maxamnt_loans30 ->	maximum amount of loan taken by the user in last 30 days
#
# medianamnt_loans30 ->	Median of amounts of loan taken by the user in last 30 days
#
# cnt_loans90 -> Number of loans taken by user in last 90 days
#
# amnt_loans90 ->	Total amount of loans taken by user in last 90 days
#
# maxamnt_loans90	-> maximum amount of loan taken by the user in last 90 days
#
# medianamnt_loans90 ->	Median of amounts of loan taken by the user in last 90 days
#
# payback30 ->	Average payback time in days over last 30 days
#
# payback90 ->	Average payback time in days over last 90 days
#
# pcircle ->	telecom circle
#
# pdate ->	date

# %%
#Importing some libary to import the dataset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#Import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing the dataset into dataframe called df
df = pd.read_csv("Data file.csv")

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Checking top 5 records of the dataset
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
#checking the shape of the data
df.shape
# Out:
# (209593, 37)

# %% [markdown]
# So here i found that there is 209593 rows and 37 columns in the dataet.

# %%
#Checking the columns of train data
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [raw]
# Here i found that column Unnamed:0 is just index so there is no use of this column so better to drop this column.

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)#droping column
df.sample() #checking sample
# Out:
#         label       msisdn    aon  daily_decr30  daily_decr90  rental30  \
# 102591      0  95331I70371  289.0         600.0         600.0       0.0
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 102591       0.0                0.0                0.0                 0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 102591              6.0                 0.0          1.0             6
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 102591                6                 0.0        0.0        0.0      UPW
#
#              pdate
# 102591  2016-07-02
#
# [1 rows x 36 columns]

# %%
#checking datatypes of all columns present in the dataset
df.dtypes
# Out:
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# ...

# %% [markdown]
# Observation:- The columns msisdn, pcircle and pdate are with object datatypes so i have to transform or drop these columns
# for building model rest are int or float so there will be no issue for them.

# %%
#Checking information about dataset like non null, dtype etc.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %% [markdown]
# observation:- There are no missing values present in the dataset as all columns have 209593 values.

# %%
#Checking missing values
df.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# ...

# %% [markdown]
# So here also we can see that there is no missing value present in the dataset.

# %%
#Checking sample
df.sample()
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 121047      1  45264I90583  1144.0     79.806333     79.806333    4664.5
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 121047    4664.5                1.0                0.0              1539  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 121047              6.0                 0.0          4.0            24
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 121047                6                 0.0        2.5        2.5      UPW
#
#              pdate
# 121047  2016-06-19
#
# [1 rows x 36 columns]

# %% [markdown]
# Here i will drop column msisdn as this is phone number of customer and phone number is not impactful to predict the target.

# %%
df.drop(['msisdn'],axis=1,inplace = True)
df.sample()
# Out:
#        label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 19430      1  329.0        64.872        64.872    546.72    546.72
#
#        last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 19430                2.0                0.0              1539              8
#
#        ...  maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 19430  ...              6.0                 0.0          6.0            36
#
#        maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 19430                6                 0.0   4.333333   4.333333      UPW
#
#             pdate
# 19430  2016-06-17
#
# [1 rows x 35 columns]

# %% [raw]
# SUMMARY STATISTICS

# %%
df.describe()# This will give statistical information about dataset.
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %% [markdown]
# Key Observation:-
#
# 1. There are 209593 rows count available across all column this also proves there is no missing record present in the dataset.
#
# 2. Standard Deviation is very high across all columns. This proves that the range is very high and data is spread.
#
# 3. Mean is higher than median across columns so the data has skewness which is right skewed.
#
# 4. The difference between 75 percentile and maximum is very high. By this i can say that there is heavy outliers present in the
#    dataset.

# %% [raw]
# Feature Engineering

# %%
#I have pdate column which is date column with object datatype. I have to transform date into parts so i can better use this column
df['pdate']=pd.to_datetime(df['pdate'])
df['Month']=df['pdate'].apply(lambda x:x.month)
df['Day']=df['pdate'].apply(lambda x:x.day)
df['Year']=df['pdate'].apply(lambda x:x.year)

# %%
df.drop(['pdate'],axis=1,inplace=True) #This will drop column pdate 
df.sample()#checking sample of data
# Out:
#        label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 66144      1  322.0        8105.6        8142.0    1783.6   2723.24
#
#        last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 66144                8.0                0.0              1547              6
#
#        ...  cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# 66144  ...         10.0            60                6                 0.0
#
#        payback30  payback90  pcircle  Month  Day  Year
# 66144        4.0        5.9      UPW      7   26  2016
#
# [1 rows x 37 columns]

# %% [markdown]
# # Data Visulization

# %%
#Checking missing values by using Graph
sns.heatmap(df.isnull())

# %%
#Checking corelation of all columns with the target column label.
#Checking corelation of all columns with targer column
plt.figure(figsize=(25,18))
sns.heatmap(df.corr(),cmap='coolwarm',annot=True,fmt='.2f')

# %% [markdown]
# Observation:-
#
# 1. Postive corelated columns :- amnt_loans90, cnt_loans30, amnt_loans30, medianamnt_ma_rech30 etc are postive corelated columns
#    with target data.
#
# 2. There is no negatively corelated column with target column label except of fr_da_rech90.
#
# 3. Highest +ve corelated column with target data = cnt_ma_rech30
#
# 4. Highest -ve corelated column with target data = fr_da_rech90

# %%
#Checking count of my target varibles
plt.figure(figsize=(5,5))
sns.countplot(df['label'])
plt.title("Distribution:{1:success, 0:failure}")
plt.show()
print("Value counts for each lebel->")
df1 = pd.concat([df['label'].value_counts(), 
                df['label'].value_counts(normalize=True).mul(100)],axis=1, keys=('counts','percentage%'))
print(df1)
# Out:
# Value counts for each lebel->
#    counts  percentage%
# 1  183431    87.517713
# 0   26162    12.482287

# %% [markdown]
# Observaation:- here i found that no of times when user paid back the credit amount successfully is very high 183431 times which cover 87.51%  data than the no of time when user fails to pay back the credit aount 26162 times which covers 12.48% data. This shows that the data is not good balance.

# %%
#Checking Count of Soil_Type
plt.figure(figsize=(5,5))
sns.countplot(df['pcircle'])
plt.title("Telecom Circle")
plt.show()
df['pcircle'].value_counts()
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %% [markdown]
# So here i found that there is single value of telecom circle available across all column. It is better to drop this column as
# the uniform value across all column doesnot help during model building.

# %%
df.drop(['pcircle'],axis=1,inplace=True)#droping column pcircle
df.sample()#Checking sample of amended data
# Out:
#        label   aon  daily_decr30  daily_decr90  rental30  rental90  \
# 56202      1  79.0          96.6          96.6    369.72    369.72
#
#        last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 56202                4.0                0.0               773             11
#
#        ...  medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 56202  ...                 0.0          8.0            48                6
#
#        medianamnt_loans90  payback30  payback90  Month  Day  Year
# 56202                 0.0       2.25       2.25      6   18  2016
#
# [1 rows x 36 columns]

# %%
# barplot of age on networks vs label
sns.catplot(kind = 'bar', data = df, y = 'aon', x = 'label')
plt.title('Age on Cellular Networks vs label')
plt.show()

# %% [markdown]
# Here we can see that customer who has maximum age on cellular networks has not return to credit with 5 days maximum times than
# the customer whose afe on cellular networks is minimum has return the credit amount within the 5 days.

# %%
#Ploting lineplot to understand distribution in more efficient way
plt.figure(figsize=(18,10))
sns.lineplot(x="Month", y="rental30", hue='label', data=df)
plt.show()

# %% [markdown]
# Here we can see that when customer maintain his account balance over last 30 days high then there is maximum time he will
# return the credit amount. The maximum return in 8th month.

# %%
#Checking relation between average maintain price over 30 days with label
sns.scatterplot(x="rental30",y="label",data=df)

# %% [markdown]
# We can see ther is outliers present however when avearge maintain balance increase then chance to return credit amount increase

# %%
#Ploting lineplot to understand distribution in more efficient way
plt.figure(figsize=(18,10))
sns.lineplot(x="Month", y="cnt_da_rech30", hue='label', data=df)
plt.show()

# %% [markdown]
# We can see when no of time account got recharge high there is maximum chance to return the credit. in 7 th month the return of
# credit amount is high.

# %%
#Checking the distribution of all columns by plotting histogram
df.hist(edgecolor="red",linewidth=1.5,figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026E2B1F3280>,
# ...
#       dtype=object)

# %% [markdown]
# After plotting histogram we can see that there is no column is normally distributed.

# %% [raw]
# I have some negative values in the dataset so first i have to get rid of that.

# %%
num = df._get_numeric_data()

# %%
num[num < 0] = 0

# %%
df.sample()
# Out:
#        label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 70554      1  1054.0   6093.579333       6227.69    440.78    524.78
#
#        last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 70554               39.0                0.0             11874              0
#
#        ...  medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 70554  ...                 0.0          1.0             6                6
#
#        medianamnt_loans90  payback30  payback90  Month  Day  Year
# 70554                 0.0        0.0        0.0      7   28  2016
#
# [1 rows x 36 columns]

# %% [raw]
# Outliers Detection

# %%
collist = df.columns.values
ncol=12
nrows=10

# %%
plt.figure(figsize = (ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color ='green',orient='v')
    plt.tight_layout()

# %% [raw]
# We can see maximum column has outliers

# %%
df.drop(['Year'],axis=1,inplace=True)# The same value across all column is no useful.

# %%
df.head(40)
# Out:
#     label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0       0   272.0   3055.050000   3065.150000    220.13    260.13
# 1       1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2       1   535.0   1398.000000   1398.000000    900.13    900.13
# 3       1   241.0     21.228000     21.228000    159.42    159.42
# 4       1   947.0    150.619333    150.619333   1098.90   1098.90
# 5       1   568.0   2257.362667   2261.460000    368.13    380.13
# 6       1   545.0   2876.641667   2883.970000    335.75    402.90
# 7       1   768.0  12905.000000  17804.150000    900.35   2549.11
# 8       1  1191.0     90.695000     90.695000   2287.50   2287.50
# 9       1   536.0     29.357333     29.357333    612.96    612.96
# 10      1  1511.0     12.896000     12.896000    790.44    790.44
# 11      0    82.0     65.166667     65.166667    326.20    326.20
# 12      1   154.0    227.041000    227.041000    240.41    240.41
# ...

# %% [raw]
# Outliers Treatment

# %%
from scipy.stats import zscore
import numpy as np
z = np.abs(zscore(df))
threshold =3
new_df = df[(z<3).all(axis=1)]
new_df
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
df.shape
# Out:
# (209593, 35)

# %%
#Percentage Loss of data after removing outliers
percentage_loss=((209593-161457)/209593)*100
percentage_loss
# Out:
# 22.9664158631252

# %%
#IQR Method

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3-Q1
print(IQR)
# Out:
# label                       0.000
# aon                       736.000
# daily_decr30             7201.560
# daily_decr90             7760.098
# rental30                 3076.520
# rental90                 3901.530
# last_rech_date_ma           6.000
# last_rech_date_da           0.000
# last_rech_amt_ma         1539.000
# cnt_ma_rech30               4.000
# fr_ma_rech30                6.000
# sumamnt_ma_rech30        8470.000
# medianamnt_ma_rech30     1154.000
# medianmarechprebal30       72.000
# cnt_ma_rech90               6.000
# fr_ma_rech90                8.000
# sumamnt_ma_rech90       13683.000
# medianamnt_ma_rech90     1151.000
# medianmarechprebal90       64.710
# cnt_da_rech30               0.000
# fr_da_rech30                0.000
# cnt_da_rech90               0.000
# fr_da_rech90                0.000
# cnt_loans30                 3.000
# amnt_loans30               18.000
# maxamnt_loans30             0.000
# medianamnt_loans30          0.000
# ...

# %%
df_new1 = df[~((df<(Q1-1.5*IQR)) | (df> (Q3+1.5*IQR))).any(axis=1)]
print(df_new1.shape)
# Out:
# (57420, 35)

# %% [raw]
# By Zscore method and IQR method i found that there is huge data loss so i will use some other method to remove outliers.

# %% [raw]
# Quantile-based Flooring and Capping

# %%
df1=df
df1.shape
# Out:
# (209593, 35)

# %%
L = df1.columns

# %%
for i in L:
    df1[i] = np.where(df1[i] <df1[i].quantile(0.10), df1[i].quantile(0.10),df1[i])
    df1[i] = np.where(df1[i] > df1[i].quantile(0.90), df1[i].quantile(0.90),df1[i])

# %%
df1.shape
# Out:
# (209593, 35)

# %% [markdown]
# # Preparing dataset For Model Buiding

# %%
#Seprating independent and target variable
x= df1.drop("label",axis=1)
y= df1["label"] #Target variable

# %%
x.shape
# Out:
# (209593, 34)

# %%
y.shape
# Out:
# (209593,)

# %%
y = y.values.reshape(-1,1)
y.shape
# Out:
# (209593, 1)

# %%
#Linear Dimensionality Reduction:- Converting many number of less corelated columns into less and more related columns instead of drop any column
from sklearn.decomposition import PCA
pca = PCA(n_components = 10)
x= pca.fit_transform(x)
x.shape
# Out:
# (209593, 10)

# %%
#Removing Skewness
from sklearn.preprocessing import power_transform
x= power_transform(x,method="yeo-johnson")

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
#Finding Best Random State

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

best_rstate=0
accu=0

for i in range(30,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .25,random_state=i)
    mod = LogisticRegression()
    mod.fit(x_train,y_train)
    y_pred = mod.predict(x_test)
    tempaccu = accuracy_score(y_test,y_pred)
    
    if tempaccu>accu:
        accu = tempaccu
        best_rstate = i
        
        
        
print(f"Best Accuracy {accu*100} found on random_state {best_rstate}")
# Out:
# Best Accuracy 87.92725052004809 found on random_state 81

# %%
x_train,x_test,y_train,y_test  = train_test_split(x,y,test_size =.20,random_state =81)

# %% [raw]
# Testing with various model in one function

# %%
import sklearn
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
model = [LogisticRegression(),GaussianNB(),SVC(),DecisionTreeClassifier(),RandomForestClassifier()]

for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm = m.predict(x_test)
    print("Accuracy Score of ", m, "is :")
    print(accuracy_score(y_test,predm)*100)
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# Accuracy Score of  LogisticRegression() is :
# 87.94341468069372
# [[  116  4987]
#  [   67 36749]]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.02      0.04      5103
#          1.0       0.88      1.00      0.94     36816
#
#     accuracy                           0.88     41919
#    macro avg       0.76      0.51      0.49     41919
# weighted avg       0.85      0.88      0.83     41919
#
#
#
# Accuracy Score of  GaussianNB() is :
# 67.87614208354206
# [[ 3781  1322]
#  [12144 24672]]
#               precision    recall  f1-score   support
#
#          0.0       0.24      0.74      0.36      5103
#          1.0       0.95      0.67      0.79     36816
#
#     accuracy                           0.68     41919
#    macro avg       0.59      0.71      0.57     41919
# weighted avg       0.86      0.68      0.73     41919
#
#
#
# Accuracy Score of  SVC() is :
# 88.35134425916648
# [[  450  4653]
#  [  230 36586]]
# ...

# %% [raw]
# I found that randomForestClassifier() is performing well with good accuracy score 88.74

# %% [raw]
# Ensemble Technique

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import SGDClassifier
model = [AdaBoostClassifier(),GradientBoostingClassifier(),SGDClassifier()]

for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm = m.predict(x_test)
    print("Accuracy Score of ", m, "is :")
    print(accuracy_score(y_test,predm)*100)
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# Accuracy Score of  AdaBoostClassifier() is :
# 88.26307879481858
# [[  762  4341]
#  [  579 36237]]
#               precision    recall  f1-score   support
#
#          0.0       0.57      0.15      0.24      5103
#          1.0       0.89      0.98      0.94     36816
#
#     accuracy                           0.88     41919
#    macro avg       0.73      0.57      0.59     41919
# weighted avg       0.85      0.88      0.85     41919
#
#
#
# Accuracy Score of  GradientBoostingClassifier() is :
# 88.80221379326797
# [[ 1110  3993]
#  [  701 36115]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.22      0.32      5103
#          1.0       0.90      0.98      0.94     36816
#
#     accuracy                           0.89     41919
#    macro avg       0.76      0.60      0.63     41919
# weighted avg       0.87      0.89      0.86     41919
#
#
#
# Accuracy Score of  SGDClassifier() is :
# 87.82652257926
# [[    0  5103]
#  [    0 36816]]
# ...

# %% [raw]
# After using Ensemble Technique I found GradientBoostingClassifier is giving best model with best accuracy 88.80

# %% [raw]
# Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'ls':['deviance','exponential'],'n_estimators':[50,100,200],'criterion':['friedman_mse','mse']}
gbc = GradientBoostingClassifier()
clf = GridSearchCV(gbc,parameters)
clf.fit(x_train_b,y_train_b)
print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'ls': 'deviance', 'n_estimators': 50}

# %%
#using the finded parameters creating and testing the model
gbc = GradientBoostingClassifier(criterion='friedman_mse',n_estimators=50)
gbc.fit(x_train,y_train)
gbc.score(x_train,y_train)
predgbc= gbc.predict(x_test)
print(accuracy_score(y_test,predgbc)*100)
print(confusion_matrix(y_test,predgbc))
print(classification_report(y_test,predgbc))
# Out:
# 88.66862282020087
# [[  963  4140]
#  [  610 36206]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.19      0.29      5103
#          1.0       0.90      0.98      0.94     36816
#
#     accuracy                           0.89     41919
#    macro avg       0.75      0.59      0.61     41919
# weighted avg       0.86      0.89      0.86     41919

# %% [raw]
# Cross Validation

# %%
#Cross validate the models
models = [GradientBoostingClassifier()]

for m in models:
    score = cross_val_score(m,x,y,cv=10,scoring="accuracy")
    print("model:",m)
    print("score",score)
    print("mean score:",score.mean())
    print("standard deviation:",score.std())
# Out:
# model: GradientBoostingClassifier()
# score [0.88506679 0.88592557 0.88506679 0.88634954 0.88458419 0.88534758
#  0.88649268 0.88405935 0.88553843 0.88630183]
# mean score: 0.8854732761145078
# standard deviation: 0.0007640835110351703

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
y_pred_prob = gbc.predict_proba(x_test)[:,1]

# %%
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label= 'GradientBoostingClassifier')
plt.xlabel('False Positive rate')
plt.ylabel('True Positive Rate')
plt.title('GradientBoostingClassifier')
plt.show()

# %%
auc_score = roc_auc_score(y_test,gbc.predict(x_test))
print(auc_score)
# Out:
# 0.5860718194757744

# %% [raw]
# After using I found GradientBoostingClassifier() is best model which i will save.

# %% [markdown]
# # Model Saving

# %%
#Model Saving with best model RandomForestRegressor
import joblib 

joblib.dump(gbc,'gbcfile.obj')
# Out:
# ['gbcfile.obj']

# %% [markdown]
# # Conclusion

# %%
#Loading to see my model
gbc_from_joblib = joblib.load('gbcfile.obj')
gbc_from_joblib
# Out:
# GradientBoostingClassifier(n_estimators=50)

# %%
k=gbc_from_joblib.predict(x_test)
k
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
# Saving The predictions in csv file
import numpy as np
import pandas as pd
prediction = pd.DataFrame(k, columns=['predictions']).to_csv('Result_prediction.csv')
